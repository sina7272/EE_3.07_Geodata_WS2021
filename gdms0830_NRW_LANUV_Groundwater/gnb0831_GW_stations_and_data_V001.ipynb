# %% [markdown]
# # NRW Groundwater Data - OpenHygrisC Data Engineering
#
# OpenHygrisC Data: https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/
#
# Download gw station data: https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV.zip

# %% [markdown]
# ## My local problem with the env var PROJ_LIB

# %%
# Correct installation bug ocuuring when using OSGeo4W
import os
proj_lib = os.environ['proj_lib']
print(proj_lib)
conda_prefix = os.environ['conda_prefix']
os.environ['proj_lib'] = conda_prefix + r"\Library\share\proj"
proj_lib = os.environ['proj_lib']
print(proj_lib)
# Out:
# C:\Users\rb\Anaconda3\envs\geo\Library\share\proj
# C:\Users\rb\Anaconda3\envs\geo\Library\share\proj

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Data

# %%
data_in_dir = r"../data/OpenGeodata.NRW/OpenHygrisC/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV/"

# %%
gw_station_fname = r"opendata.gw_messstelle.csv"
gw_quality_fname = r"opendata.gw_chemischer_messwert.csv"

# %%
gw_station_pfname = data_in_dir + gw_station_fname
gw_quality_pfname = data_in_dir + gw_quality_fname
print(f"Stationsdaten:  {gw_station_pfname:s}")
print(f"Qualitätsdaten: {gw_quality_pfname:s}")
# Out:
# Stationsdaten:  ../data/OpenGeodata.NRW/OpenHygrisC/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV/opendata.gw_messstelle.csv
# Qualitätsdaten: ../data/OpenGeodata.NRW/OpenHygrisC/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV/opendata.gw_chemischer_messwert.csv

# %% [markdown]
# ## GW Station Data

# %%
df = pd.read_csv(data_in_dir + gw_station_fname, sep = ";", index_col=["sl_nr"])

# %%
df.head(10)
# Out:
#        messstelle_id                 name     e32      n32  gw_stockwerk  \
# sl_nr
# 67530       32505929  UWB-Ddorf 01285      343064  5678019           1.0
# 51044       10446746  60GP012303           292077  5645349           NaN
# 51070       87005323  58BP024606           287141  5684635           NaN
# 68442       80000290  Krinsend 0079 neu    309490  5678060           1.0
# 68518       86583852  WG102GM93-3          316741  5680237           NaN
# 61945       87005694  Weeze alt            305351  5722580           1.0
# 67603       96005816  SPE 10               456549  5716532           NaN
# 69654       80865604           Cargill M1  337378  5690675           1.0
# 68338       76398006  Lanzerath_BN_766_EB  367793  5622538           1.0
# 18990       80201581  SCHMALENEND 201      309762  5682944           1.0
#
#        grundstueck gemeinde_id gwhorizont_id      gwhorizont gwleiter_id  ...  \
# sl_nr                                                                     ...
# 67530                 05111000           NaN             NaN         NaN  ...
# 51044       privat    NL000882             5  Zwischenmittel         NaN  ...
# 51070       privat    NL001640            6D  Neurather Sand         NaN  ...
# 68442                 05166024           NaN             NaN         NaN  ...
# 68518       privat    05166032           NaN             NaN         NaN  ...
# 61945  oeffentlich    05154064           NaN             NaN         NaN  ...
# 67603       privat    05974016           NaN             NaN         NaN  ...
# 69654                 05114000           NaN             NaN         NaN  ...
# 68338                 05314000           NaN             NaN         NaN  ...
# 18990  oeffentlich    05166032           NaN             NaN         NaN  ...
#
#       beobachtung_wasserstand  \
# sl_nr
# 67530                       -
# 51044                       -
# 51070                       -
# 68442                       -
# 68518                       -
# 61945                       -
# 67603                       -
# 69654                       -
# 68338                       -
# 18990                       -
#
#                                              eigentuemer  \
# sl_nr
# 67530  Stadt Düsseldorf                              ...
# 51044  Prov. Limburg (NL)                            ...
# 51070  Prov. Limburg (NL)                            ...
# 68442  Land NRW                                      ...
# 68518  NiederrheinWasser GmbH (ehem. Niederheinwerke)...
# 61945  Land NRW                                      ...
# 67603  Fa. Spenner Zement                            ...
# 69654  Cargill Deutschland GmbH, Krefeld             ...
# 68338                                                NaN
# 18990  Land NRW                                      ...
#
#                                                betreiber filterlaenge_cm  \
# sl_nr
# 67530  Stadt Düsseldorf                              ...             NaN
# 51044  Prov. Limburg (NL)                            ...           200.0
# 51070  Prov. Limburg (NL)                            ...           500.0
# 68442                                                NaN             NaN
# 68518  NiederrheinWasser GmbH (ehem. Niederheinwerke)...           200.0
# 61945                                                NaN           600.0
# 67603  Fa. Spenner Zement                            ...             NaN
# 69654  Cargill Deutschland GmbH, Krefeld             ...             NaN
# 68338                                                NaN             NaN
# 18990  Land NRW                                      ...           200.0
#
#       sumpfrohrlaenge_cm ausbaudurchmesser_mm historischer_ruhe_wsp  \
# sl_nr
# 67530                NaN                  NaN                   NaN
# 51044                NaN                  NaN                   NaN
# 51070              300.0                  NaN                   NaN
# 68442                NaN                  NaN                   NaN
# 68518                NaN                 80.0                   NaN
# 61945                0.0                125.0                   NaN
# 67603                NaN                  NaN                   NaN
# 69654                NaN                  NaN                   NaN
# 68338                NaN                  NaN                   NaN
# 18990              100.0                125.0                   NaN
#
#       einbaulaenge_cm oberkante_filter_cm unterkante_filter_cm
# sl_nr
# 67530             NaN                 NaN                  NaN
# 51044         16893.0             -3333.0              -3533.0
# 51070         32667.0            -29083.0             -29583.0
# 68442          1517.0              4832.0               4832.0
# 68518          5400.0              1413.0               1213.0
# 61945           796.0              1721.0               1121.0
# 67603          6000.0              5191.0               5191.0
# 69654             NaN                 NaN                  NaN
# 68338          1610.0              3790.0               3790.0
# 18990          1065.0              3927.0               3727.0
#
# [10 rows x 38 columns]

# %%
num_total = df.shape[0]
df.shape
# Out:
# (71120, 38)

# %% [markdown]
# ## Challange: Coordinates obfuscation

# %%
# Add column for precision
df["genau"] = -999

# If the coord data is numeric then the precision is 1m
idx_coords_1m_prec = (df["e32"].str.isnumeric() == True) 
df.loc[idx_coords_1m_prec, "genau"] = 1

# Some stations don't have coordinates
# e32 and n32 strings are either NaN (Null) or "xx"
#idx_coords_null = df["e32"].isnull() | df["n32"].isnull()
#idx_coords_xx = (df.loc[~idx_coords_null,"e32"].str == "xx") | (df.loc[~idx_coords_null,"n32"].str == "xx")
#idx_coords_missing = idx_coords_null | idx_coords_xx

idx_coords_missing = (df["e32"].str.len() < 6) | (df["e32"].isnull() == True)
df.loc[idx_coords_missing, "genau"] = -999

# If coord data is avaliable but not numeric, then the numbers have been obscured with "XX" for the two least significant decimals.
idx_coords_100m_prec = ~idx_coords_missing &  ~(df["e32"].str.isnumeric() & df["n32"].str.isnumeric())
df.loc[idx_coords_100m_prec, "genau"] = 100

# %%
#ä check if all records have been matched
num_of_1m_prec = df[df["genau"] == 1].shape[0]
num_of_100m_prec = df[df["genau"] == 100].shape[0]
num_of_no_prec = df[df["genau"] == -999].shape[0]

num_check = num_of_1m_prec + num_of_100m_prec + num_of_no_prec

print(f"total num of recs:                        {num_total:6d}")
print(f"number of recs with 1m coord precision:   {num_of_1m_prec:6d}")
print(f"number of recs with 100m coord precision: {num_of_100m_prec:6d}")
print(f"number of recs with no coords:            {num_of_no_prec:6d}")
print(f"check sum:                                {num_check:6d}")

assert num_check == num_total, "ERROR. Mismatch in numbers of stations"
# Out:
# total num of recs:                         71120
# number of recs with 1m coord precision:    59280
# number of recs with 100m coord precision:  11810
# number of recs with no coords:                30
# check sum:                                 71120

# %%
df.loc[idx_coords_1m_prec,"e32num"] = df.loc[idx_coords_1m_prec,"e32"].astype(float)
df.loc[idx_coords_1m_prec,"n32num"] = df.loc[idx_coords_1m_prec,"n32"].astype(float)

# %%
df.loc[idx_coords_100m_prec,"e32num"] = (df.loc[idx_coords_100m_prec,"e32"].str[:-2]+"00").astype(float)
df.loc[idx_coords_100m_prec,"n32num"] = (df.loc[idx_coords_100m_prec,"n32"].str[:-2]+"00").astype(float)

# %%
df.loc[idx_coords_missing,"e32num"] = -999.9
df.loc[idx_coords_missing,"n32num"] = -999.9

# %%
df[["e32","e32num","n32","n32num","genau"]].to_csv("check.csv")

# %% [markdown]
# ## Geopandas

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# remove records without coords
df2 = df[df["genau"] > 0]

# %%
# %%time
gdf = gpd.GeoDataFrame(df2, geometry=gpd.points_from_xy(df2.e32num, df2.n32num), crs="EPSG:25832")
# Out:
# Wall time: 4.85 s

# %%
# %%time
# This takes 90 secs on my computer
# gdf.to_file("GW_Stations.gpkg", layer='GW Stations', driver="GPKG")
# Out:
# Wall time: 0 ns

# %% [markdown]
# ## Inline SQL: `create schema gw`

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT * FROM information_schema.schemata
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 5 rows affected.
# [('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'public', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None),
#  ('env_db', 'gw', 'env_master', None, None, None, None)]

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS gw AUTHORIZATION env_master
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# SELECT * FROM information_schema.schemata
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 5 rows affected.
# [('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'public', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None),
#  ('env_db', 'gw', 'env_master', None, None, None, None)]

# %% [markdown]
# ## PostGIS: Upload GeoDataFrame with `gdf.to_postgis()`
#
# Dependencies:
# * psycopg2
# * geoalchemy2

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("postgresql://env_master:xxxxxx@localhost/env_db")

# %%
# %%time
gdf.to_postgis(con=engine, name="gw_stations", schema="gw", index=True, chunksize=100, if_exists="replace")
# Out:
# Wall time: 7.5 s

# %% [markdown]
# ## Quality Data

# %%
print(gw_quality_pfname)
# Out:
# ../data/original/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV/opendata.gw_chemischer_messwert.csv

# %%
fh = open(data_pfname,"r", encoding = "utf-8", newline = '')
s = fh.readline()
s = s.replace('"', '').strip()
header_de = s[1:].split(';')
header_de
# Out:
# ['sl_nr',
#  'messstelle_id',
#  'pna_id',
#  'datum_pn',
#  'stoff_nr',
#  'probengut',
#  'messergebnis_c',
#  'messergebnis_hinweis',
#  'bestimmungsgrenze',
#  'masseinheit',
#  'trennverfahren',
#  'verfahren',
#  'vor_ort',
#  'herkunft',
#  'aktual_dat',
#  'erstell_dat']

# %%
df_qual_header = pd.read_csv(data_pfname, sep = ";", dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str }, nrows = 5)

# %%
df_qual_header
# Out:
#      sl_nr  messstelle_id       pna_id  datum_pn  stoff_nr    probengut  \
# 0  2903561       59620687  5/2005/4599  20051018      1164  Grundwasser
# 1  2903564       59620687  5/2005/4599  20051018      1061  Grundwasser
# 2  2903565       59620687  5/2005/4599  20051018      1011  Grundwasser
# 3  2903584       59620389  5/2005/5002  20051114      1011  Grundwasser
# 4  2903585       59620080  5/2005/5001  20051111      1061  Grundwasser
#
#   messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# 0       22.00000                  NaN                NaN        µg/l
# 1        6.80000                  NaN                NaN           -
# 2       12.80000                  NaN                NaN          °C
# 3       12.30000                  NaN                NaN          °C
# 4        7.40000                  NaN                NaN           -
#
#   trennverfahren                   verfahren vor_ort    herkunft  aktual_dat  \
# 0   Gesamtgehalt    DIN 38406-E22 MAERZ 1988          HYGC_BR-AR    20051205
# 1   Gesamtgehalt    DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR    20051205
# 2   Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR    20051205
# 3   Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR    20051205
# 4   Gesamtgehalt    DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR    20051205
#
#    erstell_dat
# 0     20051205
# 1     20051205
# 2     20051205
# 3     20051205
# 4     20051205

# %%
# df_qual = pd.read_csv(data_pfname, sep = ";", index_col=["sl_nr", "aktual_dat"], dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str })
df_qual = pd.read_csv(data_pfname, sep = ";", index_col=["sl_nr"], dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str })

# %%
# duplictaes in index?
df[df.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [messstelle_id, name, e32, n32, gw_stockwerk, grundstueck, gemeinde_id, gwhorizont_id, gwhorizont, gwleiter_id, gwleiter, einrichtungsgrund, gwk_lage_auf_id, gwk_lage_id, gwk_monitoring_auf_id, gwk_monitoring_id, messprogramm, turnus_wasserstand, freigabe_wstd, freigabe_chemie, freigabe_lage, wasserstandsmessstelle, guetemessstelle, im_wrrl_messnetz_chemie, im_wrrl_messnetz_wasserstand, messstellenart, wasserart, labor, beobachtung_wasserstand, eigentuemer, betreiber, filterlaenge_cm, sumpfrohrlaenge_cm, ausbaudurchmesser_mm, historischer_ruhe_wsp, einbaulaenge_cm, oberkante_filter_cm, unterkante_filter_cm, genau]
# Index: []
#
# [0 rows x 39 columns]

# %%
# check if string can be converted to float
def is_float(element: str) -> bool:
    try:
        float(element)
        return True
    except ValueError:
        return False

# %%
# check if string starts with '<'
def is_less(element: str) -> bool:
    return element[0] == "<"

# %%
# check if string starts with '>'
def is_greater(element: str) -> bool:
    return element[0] == ">"

# %%
# %time idx_mess_is_float   = df_qual["messergebnis_c"].apply(is_float)
#%time idx_mess_not_float  = ~idx_mess_is_float
# %time idx_mess_is_less    = df_qual["messergebnis_c"].apply(is_less)
# %time idx_mess_is_greater = df_qual["messergebnis_c"].apply(is_greater)
# Out:
# Wall time: 2.64 s
# Wall time: 644 ms
# Wall time: 656 ms

# %%
df_qual[idx_mess_is_less].shape
# Out:
# (1974713, 15)

# %%
assert idx_mess_is_float.sum() + (~idx_mess_is_float).sum() == df_qual.shape[0], "mess has either to be float or not float"

# %%
# ((idx_mess_is_less | idx_mess_is_greater) == idx_mess_not_float).value_counts()
assert ((idx_mess_is_less | idx_mess_is_greater) != (~idx_mess_is_float)).sum() == 0, "'not float' supposed to come from '<' or '>' but nothing else."

# %%
# Print records which are neither less nor greater nor float -> should be empty data frame
assert df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float].shape[0] == 0
print(df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float])
# Out:
# Empty DataFrame
# Columns: [messstelle_id, pna_id, datum_pn, stoff_nr, probengut, messergebnis_c, messergebnis_hinweis, bestimmungsgrenze, masseinheit, trennverfahren, verfahren, vor_ort, herkunft, aktual_dat, erstell_dat]
# Index: []

# %%
# res = (~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float).value_counts()
res = (idx_mess_is_less | idx_mess_is_greater | idx_mess_is_float).value_counts()

# %%
res
# Out:
# True    3671913
# Name: messergebnis_c, dtype: int64

# %%
s = df_qual.loc[17716627,"messergebnis_c"]
is_less(">1.234")
# Out:
# False

# %%
df_qual
# Out:
#          messstelle_id        pna_id  datum_pn  stoff_nr    probengut  \
# sl_nr
# 2903561       59620687   5/2005/4599  20051018      1164  Grundwasser
# 2903564       59620687   5/2005/4599  20051018      1061  Grundwasser
# 2903565       59620687   5/2005/4599  20051018      1011  Grundwasser
# 2903584       59620389   5/2005/5002  20051114      1011  Grundwasser
# 2903585       59620080   5/2005/5001  20051111      1061  Grundwasser
# ...                ...           ...       ...       ...          ...
# 2882791       10407406  1/2004/91121  20041026      1331  Grundwasser
# 2882792       10407406  1/2004/91121  20041026      1472  Grundwasser
# 2882793       10407406  1/2004/91121  20041026      1477  Grundwasser
# 2882794       10407406  1/2004/91121  20041026      1521  Grundwasser
# 2882795       10407406  1/2004/91121  20041026      1690  Grundwasser
#
#         messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# sl_nr
# 2903561       22.00000                  NaN                NaN        µg/l
# 2903564        6.80000                  NaN                NaN           -
# 2903565       12.80000                  NaN                NaN          °C
# 2903584       12.30000                  NaN                NaN          °C
# 2903585        7.40000                  NaN                NaN           -
# ...                ...                  ...                ...         ...
# 2882791       19.20000                  NaN                NaN        mg/l
# 2882792        5.13000                  NaN                NaN      mmol/l
# 2882793        0.35000                  NaN                NaN      mmol/l
# 2882794        0.50000                  NaN                NaN        mg/l
# 2882795        0.00000                  NaN                NaN        1/ml
#
#         trennverfahren                          verfahren vor_ort    herkunft  \
# sl_nr
# 2903561   Gesamtgehalt           DIN 38406-E22 MAERZ 1988          HYGC_BR-AR
# 2903564   Gesamtgehalt           DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR
# 2903565   Gesamtgehalt         DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR
# 2903584   Gesamtgehalt         DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR
# 2903585   Gesamtgehalt           DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR
# ...                ...                                ...     ...         ...
# 2882791   Gesamtgehalt         DIN 38405-D19 FEBRUAR 1988           HYGC_BR-K
# 2882792   Gesamtgehalt          DIN 38409-H7-1-2 MAI 1979      ja   HYGC_BR-K
# 2882793   Gesamtgehalt          DIN 38409-H7-2-2 MAI 1979           HYGC_BR-K
# 2882794  Membranfilter             DIN 38409-H3 JUNI 1983           HYGC_BR-K
# 2882795   Gesamtgehalt  GEMAESS DIN 38411-K5 FEBRUAR 1983           HYGC_BR-K
#
#          aktual_dat  erstell_dat
# sl_nr
# 2903561    20051205     20051205
# 2903564    20051205     20051205
# 2903565    20051205     20051205
# 2903584    20051205     20051205
# 2903585    20051205     20051205
# ...             ...          ...
# 2882791    20051107     20051107
# 2882792    20051107     20051107
# 2882793    20051107     20051107
# 2882794    20051107     20051107
# 2882795    20051107     20051107
#
# [3671913 rows x 15 columns]

# %%
# %%time
df_qual.loc[idx_mess_is_less,"messergebnis_num"] = -9
df_qual.loc[idx_mess_is_greater,"messergebnis_num"] = -8
# Out:
# Wall time: 101 ms

# %%
# %%time
df_qual.loc[idx_mess_is_float,"messergebnis_num"] = df_qual.loc[idx_mess_is_float,"messergebnis_c"].astype(float)
# Out:
# Wall time: 422 ms

# %%
# Reason for not being float? XOR
idx = (~idx_mess_is_float ^ idx_mess_is_less)
df_qual[idx]
# Out:
#           messstelle_id        pna_id  datum_pn  stoff_nr    probengut  \
# sl_nr
# 17552890       60080164  0/2017/90347  20170510      1029  Grundwasser
# 1263499        10420484  1/2004/90387  20041013      1249  Grundwasser
# 2016179        24170070  2/2003/90776  20031113      1695  Grundwasser
# 2923020        26502884  2/2005/90298  20050426      1695  Grundwasser
# 2923130        26502902  2/2005/90300  20050426      1695  Grundwasser
# 2792305        10407212  1/2006/91249  20060522      1695  Grundwasser
# 6188714        86621567  8/2002/90102  20020612      1695  Grundwasser
# 6209810        86452010  8/2000/90447  20001025      1015  Grundwasser
# 6210023        86452010  8/2001/90164  20010424      1015  Grundwasser
# 6210024        86452010  8/2001/90164  20010424      1028  Grundwasser
# 12740060       10420484  1/2004/90387  20041013      1248  Grundwasser
# 2015442        26502884  2/2003/90745  20031103      1690  Grundwasser
# 2050899        24170070  2/2004/90458  20041110      1691  Grundwasser
# 2050898        24170070  2/2004/90458  20041110      1690  Grundwasser
# 2050900        24170070  2/2004/90458  20041110      1695  Grundwasser
# 6177211        86454328  8/1989/90353  19891214      1245  Grundwasser
# 6177268        86454328  8/1990/90393  19900816      1028  Grundwasser
# 12298606       86454328  8/1989/90353  19891214      1244  Grundwasser
# 2017157        26504339  2/2003/90819  20031111      1690  Grundwasser
# 2053977        26502902  2/2004/90632  20041108      1695  Grundwasser
# 1145508        10409397  1/2001/90094  20011112      1695  Grundwasser
# 2920336        24170070  2/2005/90176  20050421      1691  Grundwasser
# 2920337        24170070  2/2005/90176  20050421      1695  Grundwasser
# 2920338        24170070  2/2005/90176  20050421      1697  Grundwasser
# 2920335        24170070  2/2005/90176  20050421      1690  Grundwasser
# 2925793        24190147  2/2005/90408  20051118      1690  Grundwasser
# 6177316        86454328  8/1990/90394  19900619      1028  Grundwasser
# 1145270        10409385  1/2001/90091  20011112      1695  Grundwasser
# 1145098        10409385  1/2000/90033  20001107      1695  Grundwasser
# 1145271        10409385  1/2001/90091  20011112      1697  Grundwasser
# 2925789        24190147  2/2005/90407  20051111      1690  Grundwasser
# 6177232        86454328  8/1990/90392  19901204      1028  Grundwasser
# 6177402        86454328  8/1991/90459  19910604      1028  Grundwasser
#
#          messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# sl_nr
# 17552890       >1.00000                  NaN                NaN         FNU
# 1263499        >0.03875                  NaN                NaN        mg/l
# 2016179        >1.00000                  NaN                NaN     1/100ml
# 2923020        >1.00000                  NaN                NaN     1/100ml
# 2923130        >1.00000                  NaN                NaN     1/100ml
# 2792305        >1.00000                  NaN                NaN     1/100ml
# 6188714        >1.00000                  NaN                NaN     1/100ml
# 6209810        >0.00000                  NaN                NaN          °C
# 6210023        >0.00000                  NaN                NaN          °C
# 6210024        >0.00000                  NaN                NaN         1/m
# 12740060       >0.04991                  NaN                NaN        mg/l
# 2015442      >100.00000                  NaN                NaN        1/ml
# 2050899      >100.00000                  NaN                NaN        1/ml
# 2050898      >100.00000                  NaN                NaN        1/ml
# 2050900        >1.00000                  NaN                NaN     1/100ml
# 6177211        >0.00000                  NaN                NaN        mg/l
# 6177268        >0.00000                  NaN                NaN         1/m
# 12298606       >0.00000                  NaN                NaN        mg/l
# 2017157      >100.00000                  NaN                NaN        1/ml
# 2053977        >1.00000                  NaN                NaN     1/100ml
# 1145508        >1.00000                  NaN                NaN     1/100ml
# 2920336      >100.00000                  NaN                NaN        1/ml
# 2920337        >1.00000                  NaN                NaN     1/100ml
# 2920338      >100.00000                  NaN                NaN     1/100ml
# 2920335      >100.00000                  NaN                NaN        1/ml
# 2925793      >100.00000                  NaN                NaN        1/ml
# 6177316        >0.00000                  NaN                NaN         1/m
# 1145270        >1.00000                  NaN                NaN     1/100ml
# 1145098        >1.00000                  NaN                NaN     1/100ml
# 1145271        >1.00000                  NaN                NaN     1/100ml
# 2925789      >100.00000                  NaN                NaN        1/ml
# 6177232        >0.00000                  NaN                NaN         1/m
# 6177402        >0.00000                  NaN                NaN         1/m
#
#              trennverfahren                                    verfahren  \
# sl_nr
# 17552890       Gesamtgehalt  DIN EN ISO 7027, Abschnitt 6 - DO - C02 - 3
# 1263499        Gesamtgehalt                                          NaN
# 2016179   Nach Laborjournal                                          NaN
# 2923020   Nach Laborjournal                                          NaN
# 2923130   Nach Laborjournal                                          NaN
# 2792305        Gesamtgehalt                                          NaN
# 6188714        Gesamtgehalt                                          NaN
# 6209810   Nach Laborjournal                   DIN 38404-C4 DEZEMBER 1976
# 6210023   Nach Laborjournal                   DIN 38404-C4 DEZEMBER 1976
# 6210024        Gesamtgehalt                                          NaN
# 12740060       Gesamtgehalt                                          NaN
# 2015442   Nach Laborjournal                                          NaN
# 2050899   Nach Laborjournal                                          NaN
# 2050898   Nach Laborjournal                                          NaN
# 2050900   Nach Laborjournal                                          NaN
# 6177211        Gesamtgehalt                                          NaN
# 6177268        Gesamtgehalt                                          NaN
# 12298606       Gesamtgehalt                                          NaN
# 2017157   Nach Laborjournal                                          NaN
# 2053977   Nach Laborjournal                                          NaN
# 1145508   Nach Laborjournal                                          NaN
# 2920336   Nach Laborjournal                                          NaN
# 2920337   Nach Laborjournal                                          NaN
# 2920338   Nach Laborjournal                                          NaN
# 2920335   Nach Laborjournal                                          NaN
# 2925793   Nach Laborjournal                                          NaN
# 6177316        Gesamtgehalt                                          NaN
# 1145270   Nach Laborjournal                                          NaN
# 1145098   Nach Laborjournal                                          NaN
# 1145271   Nach Laborjournal                                          NaN
# 2925789   Nach Laborjournal                                          NaN
# 6177232        Gesamtgehalt                                          NaN
# 6177402        Gesamtgehalt                                          NaN
#
#          vor_ort     herkunft  aktual_dat  erstell_dat  messergebnis_num
# sl_nr
# 17552890      ja   LIMS_LANUV    20210619     20210619              -8.0
# 1263499             HYGC_BR-K    20050127     20050127              -8.0
# 2016179           HYGC_BR-DET    20040220     20040220              -8.0
# 2923020           HYGC_BR-DET    20051223     20051223              -8.0
# 2923130           HYGC_BR-DET    20051223     20051223              -8.0
# 2792305             HYGC_BR-K    20070808     20070808              -8.0
# 6188714             HYGC_BR-D    20030107     20030107              -8.0
# 6209810       ja    HYGC_BR-D    20030107     20030107              -8.0
# 6210023       ja    HYGC_BR-D    20030107     20030107              -8.0
# 6210024             HYGC_BR-D    20030107     20030107              -8.0
# 12740060            HYGC_BR-K    20050127     20050127              -8.0
# 2015442           HYGC_BR-DET    20040219     20040219              -8.0
# 2050899           HYGC_BR-DET    20050405     20050405              -8.0
# 2050898           HYGC_BR-DET    20050405     20050405              -8.0
# 2050900           HYGC_BR-DET    20050405     20050405              -8.0
# 6177211             HYGC_BR-D    20021121     20021121              -8.0
# 6177268             HYGC_BR-D    20021121     20021121              -8.0
# 12298606            HYGC_BR-D    20021121     20021121              -8.0
# 2017157           HYGC_BR-DET    20040220     20040220              -8.0
# 2053977           HYGC_BR-DET    20050405     20050405              -8.0
# 1145508             HYGC_BR-K    20020717     20020717              -8.0
# 2920336           HYGC_BR-DET    20051223     20051223              -8.0
# 2920337           HYGC_BR-DET    20051223     20051223              -8.0
# 2920338           HYGC_BR-DET    20051223     20051223              -8.0
# 2920335           HYGC_BR-DET    20051223     20051223              -8.0
# 2925793           HYGC_BR-DET    20051223     20051223              -8.0
# 6177316             HYGC_BR-D    20021121     20021121              -8.0
# 1145270             HYGC_BR-K    20020717     20020717              -8.0
# 1145098             HYGC_BR-K    20020717     20020717              -8.0
# 1145271             HYGC_BR-K    20020717     20020717              -8.0
# 2925789           HYGC_BR-DET    20051223     20051223              -8.0
# 6177232             HYGC_BR-D    20021121     20021121              -8.0
# 6177402             HYGC_BR-D    20021121     20021121              -8.0

# %%
df_qual["messergebnis_num"]
# Out:
# sl_nr    aktual_dat
# 2903561  20051205      22.00
# 2903564  20051205       6.80
# 2903565  20051205      12.80
# 2903584  20051205      12.30
# 2903585  20051205       7.40
#                        ...
# 2882791  20051107      19.20
# 2882792  20051107       5.13
# 2882793  20051107       0.35
# 2882794  20051107       0.50
# 2882795  20051107       0.00
# Name: messergebnis_num, Length: 3671913, dtype: float64

# %%
is_float("234.342")
# Out:
# True

# %%
# %%timeit
df_qual["messergebnis_c"].apply(is_float2)
# Out:
# 1.31 s ± 39.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def is_float2(element: str) -> bool:
    return element.replace('.','0',1).isdigit()

# %%
# %%timeit
df_qual["messergebnis_c"].apply(is_float)
# Out:
# 2.85 s ± 64.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
